# %% [markdown]
# # Task #1: Get info Box (store in Python dictionary)
#
# ### Import necessary libaries

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %% [markdown]
# ### Load the webpage

# %%
req = requests.get(url='https://en.wikipedia.org/wiki/WALL-E')
# Convert to a beautiful soup object
soup = bs(req.content)

# Print out the HTML
contents = soup.prettify()
print(contents)

# %%
info_box = soup.find(class_='infobox vevent')
info_rows = info_box.find_all('tr')
for row in info_rows:
    print(row.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 info_box = soup.find(class_='infobox vevent')
# ----> 2 info_rows = info_box.find_all('tr')
#       3 for row in info_rows:
#       4     print(row.prettify())
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
def get_content_value(row_data):
    if row_data.find('li'):
        return [li.get_text('|', strip=True).replace('\xa0', ' ') for li in row_data.find_all('li')]
    else:
        return row_data.get_text(' ', strip=True).replace('\xa0', ' ')

movie_info: dict = {}

for index, row in enumerate(info_rows):
    if index == 0:
        movie_info['title'] = row.find('th').get_text('|', strip=True)
    elif index == 1:
        continue
    else:
        header = row.find('th')
        if header:
            content_key = row.find('th').get_text('|', strip=True)
            content_value = get_content_value(row.find('td'))
            movie_info[content_key] = content_value

movie_info

# %% [markdown]
# # Task #2: Get info box for all movies

# %%
r = requests.get(url='https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films')

# Convert to a beautiful soup object
soup = bs(r.content)

contents = soup.prettify()

# %%
movies = soup.select('.wikitable.sortable i')
movies[0:10]
movies[0]

# %%
'''
" ", strip=True:
    " " - каким образом разделить объединенные строки
    strip=True - удалить пробелы в начале и конце строк
    Напримре: Productioncompany --> Production company
'''
def get_content_value(row_data):
    if row_data.find('li'):
        return [li.get_text(' ', strip=True).replace('\xa0', ' ') for li in row_data.find_all('li')]
    
    # Данный elif находит тег <br>, из-за которого не получалось на выходе получить лист
    # Например, без данного elif мы получали: 'Starring': 'Fess Parker Jeffrey Hunter John Lupton Jeff York Slim Pickens',
    # После добавления данного elif получили: 'Starring': ['Fess Parker', 'Jeffrey Hunter', 'John Lupton', 'Jeff York', 'Slim Pickens']
    elif row_data.find('br'):
        return [text for text in row_data.stripped_strings]
    else:
        return row_data.get_text(' ', strip=True).replace('xa0', ' ')


# Функция очищает тэги <sup> - который отображает текст в виде верхнего индекса
# и <span> - который отображает дату в формате "yyyy.mm.dd"
def clean_tags(soup):
    for tag in soup.find_all(['sup', 'span']):
        tag.decompose()


def get_info_box(url: str) -> dict:
    req = requests.get(url=url)
    # Convert to a beautiful soup object
    soup = bs(req.content)

    info_box = soup.find(class_='infobox vevent')
    info_rows = info_box.find_all('tr')
    
    clean_tags(soup=soup)

    movie_info = {}

    for index, row in enumerate(info_rows):
        if index == 0:
            movie_info['title'] = row.find('th').get_text(' ', strip=True)
        elif index == 1:
            continue
        else:
            header = row.find('th')
            # print(header)
            if header:
                content_key = row.find('th').get_text(' ', strip=True)
                content_value = get_content_value(row.find('td'))
                movie_info[content_key] = content_value

    return movie_info

# %%
get_info_box(url='https://en.wikipedia.org/wiki/Zorro_(1957_TV_series)#Theatrical')

# %%
# %timeit
req = requests.get(url='https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films')

# Convert to a beautiful soup object
soup = bs(req.content)

base_path = 'https://en.wikipedia.org/'

movies = soup.select('.wikitable.sortable i a')
# movies[0:10]

movie_info_list: list = []
for index, movie in enumerate(movies):
    if index % 10 == 0:
        print(index)
    try:
        relative_path = movie['href']
        full_path = base_path + relative_path
        title = movie['title']

        # В список добавляем словарь, который возвращает функция get_info_box
        movie_info_list.append(get_info_box(full_path))
    except Exception as e:
        print(movie.get_text())
        print(e)

# %%
len(movie_info_list)
# Out:
# 541

# %% [markdown]
# ### Save/Reload Movie data

# %%
# Сохранить данные в JSON формат
import json
def save_data(title, data):
    with open(file=title, mode='w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %%
save_data('disney_data.json', movie_info_list)

# %%
# Загрузить данные из JSON формата
import json
def load_data(title):
    with open(title, mode='r', encoding='utf-8') as f:
        return json.load(f)

# %%
movie_info_list = load_data(title='disney_data.json')
df = pd.DataFrame(movie_info_list)
df.loc[540]
# Out:
# title                                                         Tinker Bell
# Directed by             [Bradley Raymond (1 & 3), Klay Hall (2), Peggy...
# Story by                                                              NaN
# Based on                                                              NaN
# Produced by                                                           NaN
# Music by                                               Joel McNeely (1–6)
# Production company                                     DisneyToon Studios
# Distributed by                  [Walt Disney Studios, Home Entertainment]
# Release dates           [1, : October 28, 2008, 2, :, 3, :, 4, :, 5, :...
# Running time                                                [515 minutes]
# Country                                                     United States
# Language                                                          English
# Budget                                                                NaN
# Box office                                                            NaN
# Starring                  [Mae Whitman, Lucy Liu, Raven-Symoné, ( More )]
# Cinematography                                                        NaN
# Release date                                                          NaN
# Written by                                                            NaN
# Edited by                                                             NaN
# Languages                                                             NaN
# Narrated by                                                           NaN
# Screenplay by                                                         NaN
# Adaptation by                                                         NaN
# Countries                                                             NaN
# Color process                                                         NaN
# Production companies                                                  NaN
# Traditional Chinese                                                   NaN
# Simplified Chinese                                                    NaN
# Original title                                                        NaN
# Layouts by                                                            NaN
# Name: 540, dtype: object

# %% [markdown]
# # Task #3: Clean data

# %% [markdown]
# ### Subtasks
# - ~~Clean up references (remove [1] [2] etc)~~ функция clean_tags выше
# - Convert running time into an integer
# - Convert dates into datetime object
# - Split up the long strings
# - Convert Budget and Box office to numbers

# %%
# Split up the long strings

# %%
print(len(movie_info_list))
# Out:
# 535

# %%
df = pd.DataFrame(movie_info_list)

df
# Out:
#                                      title  \
# 0          Snow White and the Seven Dwarfs
# 1                                Pinocchio
# 2                                 Fantasia
# 3                     The Reluctant Dragon
# 4                                    Dumbo
# ..                                     ...
# 348  The Little Mermaid: Ariel's Beginning
# 349                Beverly Hills Chihuahua
# 350                          Morning Light
# 351     High School Musical 3: Senior Year
# 352                         Roadside Romeo
#
#                                            Directed by  \
# 0    [Perce Pearce, William Cottrell, Larry Morey, ...
# 1    [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...
# 2    [Samuel Armstrong, James Algar, Bill Roberts, ...
# 3    [Alfred Werker, (live action), Hamilton Luske,...
# 4    [Ben Sharpsteen, Norman Ferguson, Wilfred Jack...
# ..                                                 ...
# 348                                       Peggy Holmes
# 349                                       Raja Gosnell
# 350                                        Mark Monroe
# 351                                       Kenny Ortega
# 352                                      Jugal Hansraj
#
#                                               Story by  \
# 0    [Ted Sears, Richard Creedon, Otto Englander, D...
# 1    [Ted Sears, Otto Englander, Webb Smith, Willia...
# 2                             [Joe Grant, Dick Huemer]
# 3                                                  NaN
# 4                             [Joe Grant, Dick Huemer]
# ..                                                 ...
# 348                      [Jule Selbo, Jenny Wingfield]
# 349                                       Jeff Bushell
# 350  [Roy E. Disney, Leslie DeMeuse, Thomas J. Poll...
# 351                                                NaN
# 352                                                NaN
#
#                                               Based on  \
# 0           [", Snow White, ", by the, Brothers Grimm]
# 1     [The Adventures of Pinocchio, by, Carlo Collodi]
# 2                                                  NaN
# 3                                                  NaN
# 4    [Dumbo, the Flying Elephant, by, Helen Aberson...
# ..                                                 ...
# 348  [The Little Mermaid by Hans Christian Andersen...
# 349                                                NaN
# 350                                                NaN
# 351                 [Characters, by Peter Barsocchini]
# 352                                                NaN
#
#                                            Produced by  \
# 0                                          Walt Disney
# 1                                          Walt Disney
# 2                        [Walt Disney, Ben Sharpsteen]
# 3                                          Walt Disney
# 4                                          Walt Disney
# ..                                                 ...
# 348                                     Kendra Halland
# 349  [David Hoberman, Todd Lieberman, John Jacobs, ...
# 350                                     Morgan Sackett
# 351                     [Bill Borden, Barry Rosenbush]
# 352                                      Aditya Chopra
#
#                                          Music by       Production company  \
# 0    [Frank Churchill, Leigh Harline, Paul Smith]  Walt Disney Productions
# 1                  [Leigh Harline, Paul J. Smith]  Walt Disney Productions
# 2                                        See plot  Walt Disney Productions
# 3                  [Frank Churchill, Larry Morey]  Walt Disney Productions
# 4               [Frank Churchill, Oliver Wallace]  Walt Disney Productions
# ..                                            ...                      ...
# 348                                  James Dooley                      NaN
# 349                                Heitor Pereira                      NaN
# 350     [Ric Markmann, Dan Pinella, Chris Wagner]     Walt Disney Pictures
# 351                                David Lawrence                      NaN
# 352                                Salim–Sulaiman                      NaN
#
#                                         Distributed by  \
# 0                                   RKO Radio Pictures
# 1                                   RKO Radio Pictures
# 2                                   RKO Radio Pictures
# 3                                   RKO Radio Pictures
# 4                                   RKO Radio Pictures
# ..                                                 ...
# 348             Walt Disney Studios Home Entertainment
# 349             [Walt Disney Studios, Motion Pictures]
# 350             [Walt Disney Studios, Motion Pictures]
# 351                Walt Disney Studios Motion Pictures
# 352  [Walt Disney Studios Motion Pictures, (India, ...
#
#                                          Release dates Running time  ...  \
# 0    [December 21, 1937 ( Carthay Circle Theatre ),...   83 minutes  ...
# 1    [February 7, 1940 ( Center Theatre ), February...   88 minutes  ...
# 2                                                  NaN  126 minutes  ...
# 3                                                  NaN   74 minutes  ...
# 4    [October 23, 1941 (New York City), October 31,...   64 minutes  ...
# ..                                                 ...          ...  ...
# 348                                                NaN   77 minutes  ...
# 349  [September 18, 2008 ( El Capitan Theatre ), Oc...   91 minutes  ...
# 350                                                NaN  100 minutes  ...
# 351  [October 17, 2008 (London), October 24, 2008 (...  112 minutes  ...
# 352  [23 October 2008 (Kuwait), 24 October 2008 (In...   93 minutes  ...
#
#       Cinematography         Release date  \
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2    James Wong Howe  [November 13, 1940]
# 3       Bert Glennon      [June 27, 1941]
# 4                NaN                  NaN
# ..               ...                  ...
# 348              NaN     [26 August 2008]
# 349      Phil Méheux                  NaN
# 350      John Brooks   [October 17, 2008]
# 351    Daniel Aranyò                  NaN
# 352    Anshul Chobey                  NaN
#
#                                             Written by        Edited by  \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3    [Live-action:, Ted Sears, Al Perkins, Larry Cl...  Paul Weatherwax
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 348                                                NaN       John Royer
# 349                                                NaN   Sabrina Plisco
# 350                                        Mark Morone     Paul Crowder
# 351                                  Peter Barsocchini       Don Brochu
# 352                                      Jugal Hansraj       Arif Ahmed
#
#               Languages Narrated by                        Screenplay by  \
# 0                   NaN         NaN                                  NaN
# 1                   NaN         NaN                                  NaN
# 2                   NaN         NaN                                  NaN
# 3                   NaN         NaN                                  NaN
# 4                   NaN         NaN                                  NaN
# ..                  ...         ...                                  ...
# 348                 NaN         NaN  [Robert Reece, Evan Spiliotopoulos]
# 349  [English, Spanish]         NaN     [Analisa LaBianco, Jeff Bushell]
# 350                 NaN         NaN                                  NaN
# 351                 NaN         NaN                                  NaN
# 352    [Hindi, English]         NaN                                  NaN
#
#                                            Countries Color process  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
# ..                                               ...           ...
# 348  [Canada, Australia, United States, Philippines]           NaN
# 349                                              NaN           NaN
# 350                                              NaN           NaN
# 351                                              NaN           NaN
# 352                           [India, United States]           NaN
#
#                                   Production companies
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 348         [DisneyToon Studios, Walt Disney Pictures]
# 349  [Walt Disney Pictures, Mandeville Films, Smart...
# 350                                                NaN
# 351  [Walt Disney Pictures, Borden & Rosenbush Ente...
# 352       [Yash Raj Films, Walt Disney Pictures India]
#
# [353 rows x 25 columns]

# %%
df['Release date'] = pd.to_datetime(df['Release date'][0])
df.head()
# Out:
#                              title  \
# 0  Snow White and the Seven Dwarfs
# 1                        Pinocchio
# 2                         Fantasia
# 3             The Reluctant Dragon
# 4                            Dumbo
#
#                                          Directed by  \
# 0  [Perce Pearce, William Cottrell, Larry Morey, ...
# 1  [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...
# 2  [Samuel Armstrong, James Algar, Bill Roberts, ...
# 3  [Alfred Werker, (live action), Hamilton Luske,...
# 4  [Ben Sharpsteen, Norman Ferguson, Wilfred Jack...
#
#                                             Story by  \
# 0  [Ted Sears, Richard Creedon, Otto Englander, D...
# 1  [Ted Sears, Otto Englander, Webb Smith, Willia...
# 2                           [Joe Grant, Dick Huemer]
# 3                                                NaN
# 4                           [Joe Grant, Dick Huemer]
#
#                                             Based on  \
# 0         [", Snow White, ", by the, Brothers Grimm]
# 1   [The Adventures of Pinocchio, by, Carlo Collodi]
# 2                                                NaN
# 3                                                NaN
# 4  [Dumbo, the Flying Elephant, by, Helen Aberson...
#
#                      Produced by  \
# 0                    Walt Disney
# 1                    Walt Disney
# 2  [Walt Disney, Ben Sharpsteen]
# 3                    Walt Disney
# 4                    Walt Disney
#
#                                        Music by       Production company  \
# 0  [Frank Churchill, Leigh Harline, Paul Smith]  Walt Disney Productions
# 1                [Leigh Harline, Paul J. Smith]  Walt Disney Productions
# 2                                      See plot  Walt Disney Productions
# 3                [Frank Churchill, Larry Morey]  Walt Disney Productions
# 4             [Frank Churchill, Oliver Wallace]  Walt Disney Productions
#
#        Distributed by                                      Release dates  \
# 0  RKO Radio Pictures  [December 21, 1937 ( Carthay Circle Theatre ),...
# 1  RKO Radio Pictures  [February 7, 1940 ( Center Theatre ), February...
# 2  RKO Radio Pictures                                                NaN
# 3  RKO Radio Pictures                                                NaN
# 4  RKO Radio Pictures  [October 23, 1941 (New York City), October 31,...
#
#   Running time  ...   Cinematography Release date  \
# 0   83 minutes  ...              NaN          NaT
# 1   88 minutes  ...              NaN          NaT
# 2  126 minutes  ...  James Wong Howe          NaT
# 3   74 minutes  ...     Bert Glennon          NaT
# 4   64 minutes  ...              NaN          NaT
#
#                                           Written by        Edited by  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3  [Live-action:, Ted Sears, Al Perkins, Larry Cl...  Paul Weatherwax
# 4                                                NaN              NaN
#
#   Languages Narrated by Screenplay by Countries Color process  \
# 0       NaN         NaN           NaN       NaN           NaN
# 1       NaN         NaN           NaN       NaN           NaN
# 2       NaN         NaN           NaN       NaN           NaN
# 3       NaN         NaN           NaN       NaN           NaN
# 4       NaN         NaN           NaN       NaN           NaN
#
#   Production companies
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 25 columns]
